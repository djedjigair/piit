# %%
import pandas as pd
import numpy as py 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\djedjiga\\Desktop\\New folder\\Sales-Data-Analysis.csv")
data
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452  07-11-2022               Fries   3.49    573.07       Online
# 1       10453  07-11-2022           Beverages   2.95    745.76       Online
# 2       10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3       10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4       10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method             Manager    City
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
data.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
data.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Price', 'Quantity', 'Purchase Type',
#        'Payment Method', 'Manager', 'City'],
#       dtype='object')

# %%
data.Manager
# Out:
# 0        Tom      Jackson
# 1             Pablo Perez
# 2           Joao    Silva
# 3           Walter Muller
# 4           Walter Muller
#               ...
# 249         Walter Muller
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
data.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 14

# %%
data["Manager"] = (data["Manager"].str.strip().str.replace(r"\s+", " ", regex=True)) # to remove space between manager's names

# %%
data["Manager"].unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data["Manager"]. nunique()
# Out:
# 5

# %%
#Removing duplicates

# %%
data.head(20)
# Out:
#     Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0      10452  07-11-2022               Fries   3.49    573.07       Online
# 1      10453  07-11-2022           Beverages   2.95    745.76       Online
# 2      10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3      10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4      10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 5      10457  08-11-2022               Fries   3.49    573.07     In-store
# 6      10459  08-11-2022       Sides & Other   4.99    200.40     In-store
# 7      10460  09-11-2022             Burgers  12.99    554.27     In-store
# 8      10461  09-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 9      10462  09-11-2022               Fries   3.49    573.07     In-store
# 10     10463  09-11-2022           Beverages   2.95    677.97     In-store
# ...

# %%
data.describe()
# Out:
#            Order ID       Price    Quantity
# count    254.000000  254.000000  254.000000
# mean   10584.133858    7.102323  460.611457
# std       75.889181    4.341855  214.888699
# min    10452.000000    2.950000  200.400000
# 25%    10520.250000    3.490000  201.010000
# 50%    10583.500000    4.990000  538.880000
# 75%    10649.750000    9.950000  677.440000
# max    10713.000000   29.050000  754.430000

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.drop_duplicates(inplace= True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.Quantity = data.Quantity. astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
data.Quantity = data.Quantity.round()

# %%
data.Quantity
# Out:
# 0      573.0
# 1      746.0
# 2      200.0
# 3      570.0
# 4      201.0
#        ...
# 249    200.0
# 250    754.0
# 251    281.0
# 252    630.0
# 253    678.0
# Name: Quantity, Length: 254, dtype: float64

# %%
data.quantity = data.Quantity.astype(int)
# Out:
# C:\Users\djedjiga\AppData\Local\Temp\ipykernel_12704\2283001739.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.quantity = data.Quantity.astype(int)

# %%
data['Quantity']
# Out:
# 0      573.0
# 1      746.0
# 2      200.0
# 3      570.0
# 4      201.0
#        ...
# 249    200.0
# 250    754.0
# 251    281.0
# 252    630.0
# 253    678.0
# Name: Quantity, Length: 254, dtype: float64

# %%
data['Order ID'] = data['Order ID'].astype(int)
data['Price'] = data['Price'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    int64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 18.0+ KB

# %%
data["Date"] = pd.to_datetime(data["Date"], dayfirst=True)

# %%
data["Date"] = pd.to_datetime(data["Date"], format="mixed", dayfirst=True)

# %%
data["Date"].head()
data["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # Most Preferred Payment Method

# %%
data.head(2)
# Out:
#    Order ID       Date    Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07      Fries      3     573.0       Online
# 1     10453 2022-11-07  Beverages      2     746.0       Online
#
#   Payment Method      Manager    City
# 0      Gift Card  Tom Jackson  London
# 1      Gift Card  Pablo Perez  Madrid

# %%
data['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
data['Payment Method'].nunique()
# Out:
# 3

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
data['Payment Method'].value_counts(normalize= True)*100 #percentage
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
data['Payment Method'].value_counts().plot(kind='bar');

# %% [markdown]
# # Most Selling Product

# %% [markdown]
# # By quantity

# %%
data.head(4)
# Out:
#    Order ID       Date        Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07          Fries      3     573.0       Online
# 1     10453 2022-11-07      Beverages      2     746.0       Online
# 2     10454 2022-11-07  Sides & Other      4     200.0     In-store
# 3     10455 2022-11-08        Burgers     12     570.0     In-store
#
#   Payment Method        Manager    City
# 0      Gift Card    Tom Jackson  London
# 1      Gift Card    Pablo Perez  Madrid
# 2      Gift Card     Joao Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin

# %%
data.groupby('Product')['Quantity'].sum() #total units sold by product
# Out:
# Product
# Beverages             34988.0
# Burgers               29018.0
# Chicken Sandwiches    11133.0
# Fries                 32023.0
# Sides & Other          9800.0
# Name: Quantity, dtype: float64

# %%
data.groupby('Product')['Quantity'].sum().sort_values(ascending = False) #Largest value first
# Out:
# Product
# Beverages             34988.0
# Fries                 32023.0
# Burgers               29018.0
# Chicken Sandwiches    11133.0
# Sides & Other          9800.0
# Name: Quantity, dtype: float64

# %%
Total_quantity= data.groupby('Product')['Quantity'].sum().sort_values(ascending = False)
Total_quantity
# Out:
# Product
# Beverages             34988.0
# Fries                 32023.0
# Burgers               29018.0
# Chicken Sandwiches    11133.0
# Sides & Other          9800.0
# Name: Quantity, dtype: float64

# %%
type(Total_quantity)
# Out:
# pandas.core.series.Series

# %%
Total_quantity = Total_quantity.reset_index()
Total_quantity                                       #Form a DataFrame
# Out:
#    index             Product  Quantity
# 0      0           Beverages   34988.0
# 1      1               Fries   32023.0
# 2      2             Burgers   29018.0
# 3      3  Chicken Sandwiches   11133.0
# 4      4       Sides & Other    9800.0

# %%
type(Total_quantity)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.bar(Total_quantity['Product'], Total_quantity['Quantity'], color = ['red', 'green', 'yellow', 'pink', 'blue'], width = 0.6);
plt.title("Total_quantity")
plt.xlabel("Product")
plt.ylabel("Quantity");

# %% [markdown]
# # By revenue

# %%
data.head(2)
# Out:
#    Order ID       Date    Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07      Fries      3     573.0       Online
# 1     10453 2022-11-07  Beverages      2     746.0       Online
#
#   Payment Method      Manager    City
# 0      Gift Card  Tom Jackson  London
# 1      Gift Card  Pablo Perez  Madrid

# %%
data['Revenue'] = data['Price']* data['Quantity']
data
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries      3     573.0       Online
# 1       10453 2022-11-07           Beverages      2     746.0       Online
# 2       10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3       10455 2022-11-08             Burgers     12     570.0     In-store
# 4       10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other      4     200.0   Drive-thru
# 250     10710 2022-12-29             Burgers     12     754.0   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches      9     281.0   Drive-thru
# 252     10712 2022-12-29               Fries      3     630.0   Drive-thru
# 253     10713 2022-12-29           Beverages      2     678.0   Drive-thru
#
#     Payment Method        Manager    City  revenue  Revenue
# ...

# %%
data.groupby('Product')['Revenue'].sum().sort_values(ascending = False)
# Out:
# Product
# Burgers               348216.0
# Fries                 109929.0
# Chicken Sandwiches    104217.0
# Beverages              69976.0
# Sides & Other          39200.0
# Name: Revenue, dtype: float64

# %%
Total_revenue = data.groupby('Product')['Revenue'].sum().sort_values(ascending =False)
Total_revenue
# Out:
# Product
# Burgers               348216.0
# Fries                 109929.0
# Chicken Sandwiches    104217.0
# Beverages              69976.0
# Sides & Other          39200.0
# Name: Revenue, dtype: float64

# %%
Total_revenue = Total_revenue.reset_index()

# %%
Total_revenue
# Out:
#               Product   Revenue
# 0             Burgers  348216.0
# 1               Fries  109929.0
# 2  Chicken Sandwiches  104217.0
# 3           Beverages   69976.0
# 4       Sides & Other   39200.0

# %%
plt.bar(Total_revenue['Product'],Total_revenue['Revenue'] ,color= ['green', 'yellow', 'pink', 'red', 'blue'], width = 0.8);
plt.title('Top Products By Revenue')
plt.xlabel('Product')
plt.ylabel('Revenue');

# %% [markdown]
# # City With Most Revenue

# %%
data.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
data.City.nunique()
# Out:
# 5

# %%
data.groupby('City')['Revenue'].sum().sort_values(ascending = False)
# Out:
# City
# Lisbon    211853.0
# London    183443.0
# Madrid    118706.0
# Berlin     88071.0
# Paris      69465.0
# Name: Revenue, dtype: float64

# %%
City_revenue= data.groupby('City')['Revenue'].sum().sort_values(ascending = False)

# %%
City_revenue
# Out:
# City
# Lisbon    211853.0
# London    183443.0
# Madrid    118706.0
# Berlin     88071.0
# Paris      69465.0
# Name: Revenue, dtype: float64

# %%
City_revenue= City_revenue.reset_index()
City_revenue
# Out:
#      City   Revenue
# 0  Lisbon  211853.0
# 1  London  183443.0
# 2  Madrid  118706.0
# 3  Berlin   88071.0
# 4   Paris   69465.0

# %%
plt.bar(City_revenue['City'], City_revenue['Revenue'], color=['blue', 'yellow', 'green','red', 'gold'], width = 0.7);
plt.title('Revenue By City')
plt.xlabel('City')
plt.ylabel('Revenue');

# %% [markdown]
# # Revenue By Day

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries      3     573.0       Online
# 1     10453 2022-11-07           Beverages      2     746.0       Online
# 2     10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3     10455 2022-11-08             Burgers     12     570.0     In-store
# 4     10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
#
#   Payment Method        Manager    City  revenue  Revenue
# 0      Gift Card    Tom Jackson  London   1719.0   1719.0
# 1      Gift Card    Pablo Perez  Madrid   1492.0   1492.0
# 2      Gift Card     Joao Silva  Lisbon    800.0    800.0
# 3    Credit Card  Walter Muller  Berlin   6840.0   6840.0
# 4    Credit Card  Walter Muller  Berlin   1809.0   1809.0

# %%
data.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    int64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
#  9   revenue         254 non-null    float64
#  10  Revenue         254 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 22.0+ KB

# %%
data.columns[data.columns.duplicated(keep=False)]
# Out:
# Index([], dtype='object')

# %%
data = data.drop(columns=['revenue'])

# %%
data
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries      3     573.0       Online
# 1       10453 2022-11-07           Beverages      2     746.0       Online
# 2       10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3       10455 2022-11-08             Burgers     12     570.0     In-store
# 4       10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other      4     200.0   Drive-thru
# 250     10710 2022-12-29             Burgers     12     754.0   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches      9     281.0   Drive-thru
# 252     10712 2022-12-29               Fries      3     630.0   Drive-thru
# 253     10713 2022-12-29           Beverages      2     678.0   Drive-thru
#
#     Payment Method        Manager    City  Revenue
# ...

# %%
data.plot('Date', 'Revenue', color= 'red', linewidth = 2);
plt.title('Revenue By Date')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# # Average Revenue

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries      3     573.0       Online
# 1     10453 2022-11-07           Beverages      2     746.0       Online
# 2     10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3     10455 2022-11-08             Burgers     12     570.0     In-store
# 4     10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
#
#   Payment Method        Manager    City  Revenue
# 0      Gift Card    Tom Jackson  London   1719.0
# 1      Gift Card    Pablo Perez  Madrid   1492.0
# 2      Gift Card     Joao Silva  Lisbon    800.0
# 3    Credit Card  Walter Muller  Berlin   6840.0
# 4    Credit Card  Walter Muller  Berlin   1809.0

# %%
data['Revenue'].mean()
# Out:
# np.float64(2643.850393700787)

# %%
round(np.float64(2643.850393700787), 2)
# Out:
# np.float64(2643.85)

# %%
data['Month']= data['Date'].dt.month   
data
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries      3     573.0       Online
# 1       10453 2022-11-07           Beverages      2     746.0       Online
# 2       10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3       10455 2022-11-08             Burgers     12     570.0     In-store
# 4       10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other      4     200.0   Drive-thru
# 250     10710 2022-12-29             Burgers     12     754.0   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches      9     281.0   Drive-thru
# 252     10712 2022-12-29               Fries      3     630.0   Drive-thru
# 253     10713 2022-12-29           Beverages      2     678.0   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11 =data[data.Month==11] 
m11
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries      3     573.0       Online
# 1       10453 2022-11-07           Beverages      2     746.0       Online
# 2       10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3       10455 2022-11-08             Burgers     12     570.0     In-store
# 4       10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 108     10568 2022-11-30           Beverages      2     678.0       Online
# 109     10569 2022-11-30       Sides & Other      4     200.0       Online
# 127     10537 2022-11-24               Fries      3     630.0   Drive-thru
# 128     10538 2022-11-24           Beverages      2     746.0   Drive-thru
# 129     10539 2022-11-24       Sides & Other      4     200.0   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11.Revenue.sum()
# Out:
# np.float64(290221.0)

# %%
m11.Revenue.mean()
# Out:
# np.float64(2568.3274336283184)

# %%
m12=data[data.Month ==12]
m12
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 110     10570 2022-12-01             Burgers     12     493.0       Online
# 111     10571 2022-12-01  Chicken Sandwiches      9     201.0       Online
# 112     10572 2022-12-01               Fries      3     573.0       Online
# 113     10573 2022-12-01           Beverages      2     678.0       Online
# 114     10574 2022-12-01       Sides & Other      4     200.0       Online
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other      4     200.0   Drive-thru
# 250     10710 2022-12-29             Burgers     12     754.0   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches      9     281.0   Drive-thru
# 252     10712 2022-12-29               Fries      3     630.0   Drive-thru
# 253     10713 2022-12-29           Beverages      2     678.0   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m12.Revenue.sum()
# Out:
# np.float64(381317.0)

# %%
m12.Revenue.mean()
# Out:
# np.float64(2704.375886524823)

# %% [markdown]
# # Standar deviation Of Revenue and Quantity

# %%
data['Revenue'].std()
# Out:
# 2335.33689482098

# %%
data['Quantity'].std()
# Out:
# 214.97943096363838

# %% [markdown]
# # Variance Of Revenue and quantity

# %%
data['Quantity'].var()
# Out:
# 46216.155737449764

# %%
data['Revenue'].var()
# Out:
# 5453798.412312097

# %% [markdown]
# # Is Revenue Increasing or Decreasing Overtime

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries      3     573.0       Online
# 1     10453 2022-11-07           Beverages      2     746.0       Online
# 2     10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3     10455 2022-11-08             Burgers     12     570.0     In-store
# 4     10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
#
#   Payment Method        Manager    City  Revenue  Month
# 0      Gift Card    Tom Jackson  London   1719.0     11
# 1      Gift Card    Pablo Perez  Madrid   1492.0     11
# 2      Gift Card     Joao Silva  Lisbon    800.0     11
# 3    Credit Card  Walter Muller  Berlin   6840.0     11
# 4    Credit Card  Walter Muller  Berlin   1809.0     11

# %%
m11 = data[data['Month']==11]
m11
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries      3     573.0       Online
# 1       10453 2022-11-07           Beverages      2     746.0       Online
# 2       10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3       10455 2022-11-08             Burgers     12     570.0     In-store
# 4       10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 108     10568 2022-11-30           Beverages      2     678.0       Online
# 109     10569 2022-11-30       Sides & Other      4     200.0       Online
# 127     10537 2022-11-24               Fries      3     630.0   Drive-thru
# 128     10538 2022-11-24           Beverages      2     746.0   Drive-thru
# 129     10539 2022-11-24       Sides & Other      4     200.0   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11['Revenue'].sum()
# Out:
# np.float64(290221.0)

# %%
m12= data[data.Month ==12]
m12
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 110     10570 2022-12-01             Burgers     12     493.0       Online
# 111     10571 2022-12-01  Chicken Sandwiches      9     201.0       Online
# 112     10572 2022-12-01               Fries      3     573.0       Online
# 113     10573 2022-12-01           Beverages      2     678.0       Online
# 114     10574 2022-12-01       Sides & Other      4     200.0       Online
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other      4     200.0   Drive-thru
# 250     10710 2022-12-29             Burgers     12     754.0   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches      9     281.0   Drive-thru
# 252     10712 2022-12-29               Fries      3     630.0   Drive-thru
# 253     10713 2022-12-29           Beverages      2     678.0   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m12.Revenue.sum()
# Out:
# np.float64(381317.0)

# %%
data['Month'].unique()
# Out:
# array([11, 12], dtype=int32)

# %% [markdown]
# # Average Quantity Sold And Average Revenue For Each Product

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries      3     573.0       Online
# 1     10453 2022-11-07           Beverages      2     746.0       Online
# 2     10454 2022-11-07       Sides & Other      4     200.0     In-store
# 3     10455 2022-11-08             Burgers     12     570.0     In-store
# 4     10456 2022-11-08  Chicken Sandwiches      9     201.0     In-store
#
#   Payment Method        Manager    City  Revenue  Month
# 0      Gift Card    Tom Jackson  London   1719.0     11
# 1      Gift Card    Pablo Perez  Madrid   1492.0     11
# 2      Gift Card     Joao Silva  Lisbon    800.0     11
# 3    Credit Card  Walter Muller  Berlin   6840.0     11
# 4    Credit Card  Walter Muller  Berlin   1809.0     11

# %%
data.groupby('Product')[['Quantity', 'Revenue']].mean()
# Out:
#                       Quantity      Revenue
# Product
# Beverages           699.760000  1399.520000
# Burgers             558.038462  6696.461538
# Chicken Sandwiches  214.096154  2004.173077
# Fries               627.901961  2155.470588
# Sides & Other       200.000000   800.000000

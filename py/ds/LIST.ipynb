# %% [markdown]
# # LIST

# %%
# Python - Interpreted Language - Line by Line

# %%
# Run a Line (Execute) - Shift + Enter

# %% [markdown]
# ## 1st List

# %%
x = [1, 2, 3, 5]  #variable which gets stored in Environment

# %%
x
# Out:
# [1, 2, 3, 5]

# %%
print(x)
# Out:
# [1, 2, 3, 5]

# %%
type(x)
# Out:
# list

# %% [markdown]
# ## 2nd List

# %%
x1 = [1, 10, 15.67, "Nayeema" , "PIIT" , True, 45, 10]  # List of mixed data type - no, string, Logical
#duplicate 10 values 
# for string, the quotes should matching - " " , ' '

# %%
type(x1)
# Out:
# list

# %%
print(x1)
# Out:
# [1, 10, 15.67, 'Nayeema', 'PIIT', True, 45, 10]

# %%
# lenghth of the list

# %%
len(x1)
# Out:
# 8

# %% [markdown]
# ### Ordered
# filter by position

# %%
x1[0]  #first position from 0 value between square bracket [ index ]
# Out:
# 1

# %%
x1[4]
# Out:
# 'PIIT'

# %% [markdown]
# ### Change Values/Mutable

# %%
x1[4]= "Mandal" #assign new value at position 4 + 1 in variable x1

# %%
print(x1)
# Out:
# [1, 10, 15.67, 'Nayeema', 'Mandal', True, 45, 10]

# %% [markdown]
# #### 3rd List

# %%
x
# Out:
# [1, 2, 3, 5]

# %%
x1
# Out:
# [1, 10, 15.67, 'Nayeema', 'Mandal', True, 45, 10]

# %%
x2= x + x1

# %%
print(x2)
# Out:
# [1, 2, 3, 5, 1, 10, 15.67, 'Nayeema', 'Mandal', True, 45, 10]

# %% [markdown]
# ### Other functions of list
# .https://docs.python.org/3/library/functions.html

# %%
x.append( 'Bijata' )

# %%
x
# Out:
# [1, 2, 3, 5, 'Bijata']

# %%
x.append(100)

# %%
x
# Out:
# [1, 2, 3, 5, 'Bijata', 100]

# %%
x.insert(1, 'Syed')

# %%
x
# Out:
# [1, 'Syed', 2, 3, 5, 'Bijata', 100]

# %%
x.reverse()

# %%
x
# Out:
# [100, 'Bijata', 5, 3, 2, 'Syed', 1]

# %%
x.count(3)
# Out:
# 1

# %%
x3 = [1 , 5, 6, 17, 37, 28]

# %%
x3
# Out:
# [1, 5, 6, 17, 37, 28]

# %%
sorted(x3)
# Out:
# [1, 5, 6, 17, 28, 37]

# %%
sorted (x3,reverse=False)
# Out:
# [1, 5, 6, 17, 28, 37]

# %%
sorted(x3, reverse=True)
# Out:
# [37, 28, 17, 6, 5, 1]

# %%
print( "Hello" , 'Djedjiga')
# Out:
# Hello Djedjiga

# %% [markdown]
# ## End of Line Character

# %%
print('Djedjiga', 'suroor', sep=' & ')
# Out:
# Djedjiga & suroor

# %%
print('djedjiga', 'suroor', sep=' & ', end='...')
# Out:
# djedjiga & suroor...

# %%
print('Hello', 'Mandal', end='! ' )
# Out:
# Hello Mandal!

# %%
print( 'Hello', 'Mandal', end='\n')
print('PIIT Students')
# Out:
# Hello Mandal
# PIIT Students

# %%
print( 'Hello', 'Mandal', sep=', ', end='\n' )
print('PIIT Students')
# Out:
# Hello, Mandal
# PIIT Students

# %%
print('Djedjiga', 'Irnatene', sep='_', end='\n\n')
print( 'is a student')
# Out:
# Djedjiga_Irnatene
#
# is a student

# %% [markdown]
# ### Formatted (f) strings

# %%
name = "Djedjiga"
score = 95
print(name, score, sep=' - ')
# Out:
# Djedjiga - 95

# %%
print(name, 'scored', score, 'marks.')
# Out:
# Djedjiga scored 95 marks.

# %%
rank=1

# %%
print(f"{name} scored {score} marks and her rank was {rank}.")
# Out:
# Djedjiga scored 95 marks and her rank was 1.

# %%
name= "Amandeep"
age= 20
print(f'name of student is {name} and his\her age is {age}')
# Out:
# name of student is Amandeep and his\her age is 20

# %% [markdown]
# ## Format command

# %%
print("name : {}, score : {}" . format("suroor" , 85))
# Out:
# name : suroor, score : 85

# %%
print("name : {}, age : {}". format("Amandeep" , 20))
# Out:
# name : Amandeep, age : 20

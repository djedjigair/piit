# %%
student = {
    "name": "Djedjiga",
    "age" :30,
    "major": "data analyst"
}

# %%
student
# Out:
# {'name': 'Djedjiga', 'age': 30, 'major': 'data analyst'}

# %%
print (student ["name"])
# Out:
# Djedjiga

# %%
print (student ["age"])
# Out:
# 30

# %%
stude

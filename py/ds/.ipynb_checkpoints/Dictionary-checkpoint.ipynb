# %%
student = {
    "name": "Djedjiga",
    "age": 30,
    "major": "data analytics",
}

# %%
student
# Out:
# {'name': 'Djedjiga', 'age': 30, 'major': 'data analytics'}

# %%
print (student ["name"])
# Out:
# Djedjiga

# %%
print (student ["age"])
# Out:
# 30

# %%
student ["gpa"] =3.8

# %%
student
# Out:
# {'name': 'Djedjiga', 'age': 30, 'major': 'data analytics', 'gpa': 3.8}

# %%
student ["age"] = 32

# %%
student
# Out:
# {'name': 'Djedjiga', 'age': 30, 'major': 'data analytics', 'gpa': 3.8}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'major', 'gpa'])

# %%
student.values()
# Out:
# dict_values(['Djedjiga', 30, 'data analytics', 3.8])

# %%
for key , value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Djedjiga
# age:30
# major:data analytics
# gpa:3.8

# %%
del student ["age"]

# %%
student
# Out:
# {'name': 'Djedjiga', 'age': 30, 'major': 'data analytics', 'gpa': 3.8}

# %%
student.values()
# Out:
# dict_values(['Djedjiga', 30, 'data analytics', 3.8])
